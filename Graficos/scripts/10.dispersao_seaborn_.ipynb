# %%
# Formação Cientista de Dados - Fernando Amaral e Jones Granatyr
# Gráfico de dispersão com seaborn

# %%
# Importação das bibliotecas
import pandas as pd
import seaborn as srn
import matplotlib.pyplot as plt

# %%
# Carregamento da base de dados
base = pd.read_csv('../dados/co2.csv')
base.head()
# Out:
#   Plant    Type   Treatment  conc  uptake
# 0   Qn1  Quebec  nonchilled    95    16.0
# 1   Qn1  Quebec  nonchilled   175    30.4
# 2   Qn1  Quebec  nonchilled   250    34.8
# 3   Qn1  Quebec  nonchilled   350    37.2
# 4   Qn1  Quebec  nonchilled   500    35.3

# %%
# Gráfico de dispersão utilizando os atributos conc e uptake, agrupamento pelo type

#versão antiga da biblioteca
#srn.scatterplot(base.conc, base.uptake, hue = base.Type)
srn.scatterplot(data=base, x='conc', y='uptake', hue='Type')
plt.show()

# %%
# Seleção de registros específicos da base de dados (Quebec e Mississipi)
q = base.loc[base['Type'] == 'Quebec']
m = base.loc[base['Type'] == 'Mississippi']

# %%
# Subgráfico (1 linha e duas colunas) mostrando gráficos sobre cada região
'''
#versão antiga do seaborn, se a versão abaixo não funcionar,
#remova este comentários (3 aspas simples) e execute este bloco
plt.figure()
plt.subplot(1,2,1)
srn.scatterplot(q.conc, q.uptake).set_title('Quebec')
sns.scatterplot(x=q.conc, y=q.uptake)
srn.scatterplot(data=base, x='conc', y='uptake', hue='Type')
plt.subplot(1,2,2)
srn.scatterplot(m.conc, m.uptake).set_title('Mississippi')
plt.tight_layout()
'''

plt.figure(figsize=(10, 7))  # Ajuste o tamanho se necessário

plt.subplot(1, 3, 1)
srn.scatterplot(x=q.conc, y=q.uptake, color='blue')
plt.title('Quebec')

plt.subplot(1, 3, 2)
srn.scatterplot(x=m.conc, y=m.uptake, color='orange')
plt.title('Mississippi')

plt.subplot(1, 3, 3)
srn.scatterplot(data=base, x='conc', y='uptake', hue='Type')
plt.title('Type')

plt.tight_layout()
plt.show()

# %%
# Refrigerado e não refrigerado
ch = base.loc[base['Treatment'] == 'chilled']
nc = base.loc[base['Treatment'] == 'nonchilled']

# %%
# Gráfico somente com 'chilled' e 'nonchilled'
'''
plt.figure()
plt.subplot(1,2,1)
srn.scatterplot(ch.conc, ch.uptake).set_title('Chilled')
plt.subplot(1,2,2)
srn.scatterplot(nc.conc, nc.uptake).set_title('Non chilled')
plt.tight_layout()
'''
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
srn.scatterplot(x=ch.conc, y=ch.uptake, color='red')
plt.title('Chilled')
plt.subplot(1, 2, 2)
srn.scatterplot(x=nc.conc, y=nc.uptake, color='green')
plt.title('Non chilled')
plt.tight_layout()
plt.show()

# %%
# Carregamento de outro arquivo, cancer de esofago
base2 = pd.read_csv('../dados/esoph.csv')
base2
# Out:
#     agegp      alcgp     tobgp  ncases  ncontrols
# 0   25-34  0-39g/day  0-9g/day       0         40
# 1   25-34  0-39g/day     10-19       0         10
# 2   25-34  0-39g/day     20-29       0          6
# 3   25-34  0-39g/day       30+       0          5
# 4   25-34      40-79  0-9g/day       0         27
# ..    ...        ...       ...     ...        ...
# 83    75+      40-79       30+       1          1
# 84    75+     80-119  0-9g/day       1          1
# 85    75+     80-119     10-19       1          1
# 86    75+       120+  0-9g/day       2          2
# 87    75+       120+     10-19       1          1
#
# [88 rows x 5 columns]

# %%
# Gráfico entre os atributos 'alcgp' e 'ncontrols'
srn.catplot(x = 'alcgp', y = 'ncontrols', data = base2, jitter = False, color='red')
plt.show()
# Out:
# c:\Users\lufim\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\lufim\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Gráfico entre os atributos 'alcgp' e 'ncontrols', com agrupamento
srn.catplot(x = 'alcgp', y = 'ncontrols', data = base2, col = 'tobgp')
plt.show()
# Out:
# c:\Users\lufim\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\lufim\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
